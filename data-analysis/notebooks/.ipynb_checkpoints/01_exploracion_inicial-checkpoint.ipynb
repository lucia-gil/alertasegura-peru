# %% [markdown]
# # Exploración inicial — AlertaSegura Perú uwu
#
# Sprint 1 · Data Analysis
#
# Carga el dataset sintético (`data/reportes_sinteticos.csv`) generado con
# `scripts/generar_dataset.py` y hace una primera exploración: estructura,
# nulos, y las métricas definidas en `fields_and_metrics.md`
# (reportes por distrito, por categoría, por hora, tasa de verificación).

# %%
#holi
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

reportes = pd.read_csv("../data/reportes_sinteticos.csv", parse_dates=["created_at"])
usuarios = pd.read_csv("../data/usuarios.csv", parse_dates=["created_at"])
categorias = pd.read_csv("../data/categorias.csv")

reportes.head()
# Out:
#    id  usuario_id categoria                               descripcion  \
# 0   1          22     Bache       Pista deteriorada genera accidentes
# 1   2          39     Bache              Hueco profundo sin señalizar
# 2   3          24     Acoso  Un sujeto acosó a una mujer en la vereda
# 3   4          25     Bache              Hueco profundo sin señalizar
# 4   5           5     Acoso     Acoso a estudiantes cerca del colegio
#
#      latitud   longitud                distrito      estado  \
# 0 -12.222394 -76.928030       Villa El Salvador   PENDIENTE
# 1 -11.977605 -77.084275    San Martín de Porres  VERIFICADO
# 2 -11.964809 -77.079884              Los Olivos  VERIFICADO
# 3 -12.043686 -77.045503         Cercado de Lima   PENDIENTE
# 4 -12.157617 -76.974004  San Juan de Miraflores  VERIFICADO
#
#            created_at
# 0 2026-05-14 01:06:00
# 1 2026-06-18 01:18:00
# 2 2026-05-30 20:05:00
# 3 2026-06-17 05:42:00
# 4 2026-06-29 06:59:00

# %% [markdown]
# ## 1. Estructura y calidad de los datos

# %%
reportes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           120 non-null    int64
#  1   usuario_id   120 non-null    int64
#  2   categoria    120 non-null    str
#  3   descripcion  120 non-null    str
#  4   latitud      120 non-null    float64
#  5   longitud     120 non-null    float64
#  6   distrito     120 non-null    str
#  7   estado       120 non-null    str
#  8   created_at   120 non-null    datetime64[us]
# dtypes: datetime64[us](1), float64(2), int64(2), str(4)
# memory usage: 8.6 KB

# %%
reportes.isnull().sum()
# Out:
# id             0
# usuario_id     0
# categoria      0
# descripcion    0
# latitud        0
# longitud       0
# distrito       0
# estado         0
# created_at     0
# dtype: int64

# %%
reportes.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 2. Reportes por distrito

# %%
conteo_distrito = reportes["distrito"].value_counts()
conteo_distrito
# Out:
# distrito
# Callao                     14
# Puente Piedra              13
# Miraflores                 10
# Villa El Salvador           9
# Ate                         9
# Los Olivos                  8
# Rímac                       8
# Chorrillos                  8
# La Victoria                 6
# Comas                       6
# San Juan de Lurigancho      6
# Cercado de Lima             5
# San Juan de Miraflores      5
# Independencia               5
# Villa María del Triunfo     4
# San Martín de Porres        3
# San Isidro                  1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(y=conteo_distrito.index, x=conteo_distrito.values)
plt.title("Reportes por distrito")
plt.xlabel("N° de reportes")
plt.ylabel("Distrito")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Reportes por categoría

# %%
conteo_categoria = reportes["categoria"].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(y=conteo_categoria.index, x=conteo_categoria.values)
plt.title("Reportes por categoría")
plt.xlabel("N° de reportes")
plt.ylabel("Categoría")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Reportes por hora del día

# %%
reportes["hora"] = reportes["created_at"].dt.hour
reportes["dia_semana"] = reportes["created_at"].dt.day_name()

plt.figure(figsize=(9, 4))
sns.histplot(reportes["hora"], bins=24)
plt.title("Reportes por hora del día")
plt.xlabel("Hora")
plt.ylabel("N° de reportes")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Tasa de verificación (`estado`)

# %%
reportes["estado"].value_counts(normalize=True) * 100
# Out:
# estado
# PENDIENTE     45.833333
# VERIFICADO    40.833333
# RECHAZADO     13.333333
# Name: proportion, dtype: float64

# %%
pd.crosstab(reportes["categoria"], reportes["estado"], normalize="index") * 100
# Out:
# estado                PENDIENTE  RECHAZADO  VERIFICADO
# categoria
# Acoso                 51.851852   3.703704   44.444444
# Alumbrado deficiente  50.000000  15.384615   34.615385
# Bache                 44.000000  12.000000   44.000000
# Extorsión             33.333333  22.222222   44.444444
# Robo                  53.333333  13.333333   33.333333

# %% [markdown]
# ## 6. Mapa rápido de reportes (lat/lon)

# %%
import folium

mapa = folium.Map(location=[-12.0464, -77.0428], zoom_start=11)
for _, row in reportes.iterrows():
    folium.CircleMarker(
        location=[row["latitud"], row["longitud"]],
        radius=3,
        popup=f"{row['categoria']} — {row['distrito']}",
        color="crimson",
        fill=True,
    ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1873628bdc9fe751432105d1b0d418b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1873628bdc9fe751432105d1b0d418b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1873628bdc9fe751432105d1b0d418b1 = L.map(
#                 &quot;map_1873628bdc9fe751432105d1b0d418b1&quot;,
#                 {
#                     center: [-12.0464, -77.0428],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_345142f155a985d3063e1a4101a81767 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_345142f155a985d3063e1a4101a81767.addTo(map_1873628bdc9fe751432105d1b0d418b1);
#
#
#             var circle_marker_60ddc193148985b9891ec71c8d992087 = L.circleMarker(
#                 [-12.222394, -76.92803],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1873628bdc9fe751432105d1b0d418b1);
#
#
#         var popup_cfc1d51fab5f15f7b09eba8d4bd14468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a659f301814ecb12fb08b656167a5bd8 = $(`&lt;div id=&quot;html_a659f301814ecb12fb08b656167a5bd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bache — Villa El Salvador&lt;/div&gt;`)[0];
#                 popup_cfc1d51fab5f15f7b09eba8d4bd14468.setContent(html_a659f301814ecb12fb08b656167a5bd8);
#
#
#
#         circle_marker_60ddc193148985b9891ec71c8d992087.bindPopup(popup_cfc1d51fab5f15f7b09eba8d4bd14468)
#         ;
#
#
#
#
#             var circle_marker_f51069fd9d58db6914ae37c12bf386e7 = L.circleMarker(
#                 [-11.977605, -77.084275],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1873628bdc9fe751432105d1b0d418b1);
#
#
#         var popup_2069f2c86a3b73228c15855ca01c3dd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d49e8cb5b4de9b3aa084ebf958267dd6 = $(`&lt;div id=&quot;html_d49e8cb5b4de9b3aa084ebf958267dd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bache — San Martín de Porres&lt;/div&gt;`)[0];
#                 popup_2069f2c86a3b73228c15855ca01c3dd3.setContent(html_d49e8cb5b4de9b3aa084ebf958267dd6);
#
#
#
#         circle_marker_f51069fd9d58db6914ae37c12bf386e7.bindPopup(popup_2069f2c86a3b73228c15855ca01c3dd3)
#         ;
#
#
#
#
#             var circle_marker_d8296d0a811f72e768ce6475fed3fade = L.circleMarker(
#                 [-11.964809, -77.079884],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;crimson&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1873628bdc9fe751432105d1b0d418b1);
#
#
#         var popup_f41d31457d30f1ff5ee83dd24bea2a37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f5e3b5ca63c35c1edc33ea3ab29a775 = $(`&lt;div id=&quot;html_6f5e3b5ca63c35c1edc33ea3ab29a775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Acoso — Los Olivos&lt;/div&gt;`)[0];
#                 popup_f41d31457d30f1ff5ee83dd24bea2a37.setContent(html_6f5e3b5ca63c35c1edc33ea3ab29a775);
#
#
#
#         circle_marker_d8296d0a811f72e768ce6475fed3fade.bindPopup(popup_f41d31457d30f1ff5ee83dd24bea2a37)
#         ;
#
#
#
#
#             var circle_m

# %% [markdown]
# ## Próximos pasos (Sprint 2+)
#
# - Reemplazar el CSV por datos reales de la API/BD cuando esté disponible.
# - Script de limpieza formal (nulos, duplicados, formatos) — Sprint 2.
# - Dataset más realista de 150-300 registros — Sprint 3.
# - Modelo de zonas de riesgo (KMeans/heatmap) y dashboard — Sprint 4.
